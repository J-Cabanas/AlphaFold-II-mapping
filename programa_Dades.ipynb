# %% [markdown]
# ## Program for downloading the CATH database
# ---

# %% [markdown]
# Previous libraries that need to be downloaded.
#
# To start working, it will be necessary to create a folder to download the files and change our working directory, going to the folder we have created.
#
# ***If you want to download the complete database, type variable="YES", otherwise, if you want the test version, type variable = "NO".
# The complete database requires about 40GB.***

# %%
import os 
import pandas as pd
import wget
import requests
import json

datadir=os.path.expanduser('~/data')
RCSB_pdb=os.path.expanduser('~/data/RCSB_pdb')
variable="NO"

# %%
if os.path.exists(datadir)== False:
    os.mkdir(datadir)
    os.chdir(datadir)
    os.mkdir(RCSB_pdb)
else:
    os.chdir(datadir)

# %%
os.getcwd()
# Out:
# '/home/joanc/data'

# %% [markdown]
# To access the information found in CATH, you need the following link and then we can proceed to download.
# * Url: ftp://orengoftp.biochem.ucl.ac.uk/cath/releases/latest-release/cath-classification-data/ "file"

# %%
# !wget -nc ftp://orengoftp.biochem.ucl.ac.uk/cath/releases/latest-release/cath-classification-data/cath-domain-description-file.txt


# !wget -nc ftp://orengoftp.biochem.ucl.ac.uk/cath/releases/latest-release/cath-classification-data/cath-names.txt
# Out:
# El fichero “cath-domain-description-file.txt” ya está ahí, no se recupera.
# El fichero “cath-names.txt” ya está ahí, no se recupera.

# %% [markdown]
# ---
# ### We proceed to work with the files.
#
# We will start by creating a dictionary, which links the code that cath uses with the different hierarchies.

# %%
def read_file(file):            
    f=open(file,"r")            
    list=f.readlines()          
    f.close()                   
    return(list)
def create_dic(list):
    d={}
    d2={}
    for e in list:
        if e[0]!='#':
            v1=e.find("    ")
            cad=e[v1+4:]
            v2=cad.find('    ')
            codeCATH=e[:v1]
            codePDB=cad[:v2-3]  #we extract the last three characters because they are not part of the pdb code.
            node=cad[v2+5:-1]
            d[codeCATH]=codePDB
            d2[codeCATH]=node
    return(d,d2)

# %%
list_Hierarchy= read_file("./cath-names.txt") # We open the file containing the names of the different hierarchies that exist.
(dic_pdb,dic_node)=create_dic(list_Hierarchy)
dic_pdb
#dic_node
# Out:
# {'1': '1xmk',
#  '2': '4unu',
#  '3': '1hdo',
#  '4': '1g6x',
#  '6': '1vwx',
#  '1.10': '1xmk',
#  '1.20': '2ynz',
#  '1.25': '3ro3',
#  '1.40': '3iis',
#  '1.50': '4ayo',
#  '2.10': '3sov',
#  '2.20': '6d9n',
#  '2.30': '2o9s',
#  '2.40': '1x54',
#  '2.50': '4mxt',
#  '2.60': '4unu',
#  '2.70': '1rwh',
#  '2.80': '3nbc',
#  '2.90': '2dpf',
#  '2.100': '3ll2',
#  '2.102': '2bmo',
#  '2.105': '1n7v',
#  '2.110': '3c7x',
#  '2.115': '4n1i',
#  '2.120': '1pjx',
#  '2.130': '2oiz',
#  '2.140': '4a5s',
#  '2.150': '5d7w',
#  '2.160': '1k5c',
#  '2.170': '3f9x',
#  '2.180': '5kis',
#  '3.10': '3goe',
#  '3.15': '1ewf',
#  '3.20': '2vxn',
#  '3.30': '6n3d',
#  '3.40': '1hdo',
#  '3.50': '1lqt',
#  '3.55': '4jtm',
#  '3.60': '5xp6',
#  '3.65': '5u4h',
#  '3.70': '1ud9',
#  '3.75': '6nib',
#  '3.80': '4fs7',
#  '3.90': '2w8t',
#  '3.100': '1vq8',
#  '4.10': '1g6x',
#  '6.10': '1vwx',
#  '6.20': '3hrz',
#  '1.10.8': '1oai',
#  '1.10.10': '1xmk',
#  '1.10.12': '5jbx',
#  '1.10.15': '4c1n',
#  '1.10.20': '4cay',
#  '1.10.30': '3fgh',
#  '1.10.40': '2ptr',
#  '1.10.45': '1wvf',
#  '1.10.60': '1on2',
#  '1.10.100': '1tgr',
#  '1.10.101': '4lpq',
#  '1.10.110': '4xuw',
#  '1.10.132': '3iay',
#  '1.10.135': '1m15',
#  '1.10.140': '1cmb',
#  '1.10.150': '3b0x',
#  '1.10.155': '1af7',
#  '1.10.166': '3tk8',
#  '1.10.167': '6am3',
#  '1.10.168': '6fai',
#  '1.10.170': '1bvp',
#  '1.10.185': '1jvr',
#  '1.10.189': '1kbl',
#  '1.10.195': '1vpu',
#  '1.10.196': '1dk8',
#  '1.10.210': '4cfs',
#  '1.10.220': '2ii2',
#  '1.10.225': '1l9l',
#  '1.10.230': '2ibp',
#  '1.10.238': '1psr',
#  '1.10.239': '2aib',
#  '1.10.240': '1n3l',
#  '1.10.245': '5c5a',
#  '1.10.246': '5osw',
#  '1.10.250': '1bvp',
#  '1.10.260': '3fym',
#  '1.10.268': '4ckk',
#  '1.10.269': '2wb0',
#  '1.10.274': '1twf',
#  '1.10.275': '6n1m',
#  '1.10.285': '5gud',
#  '1.10.286': '2wsc',
#  '1.10.287': '3ouf',
#  '1.10.288': '6bm5',
#  '1.10.290': '2gai',
#  '1.10.300': '5i34',
#  '1.10.340': '1xqo',
#  '1.10.357': '2zcm',
#  '1.10.375': '2wlv',
#  '1.10.390': '5jvi',
#  '1.10.400': '1cip',
#  '1.10.405': '1d5t',
#  '1.10.418': '2vzc',
#  '1.10.420': '4bll',
#  '1.10.437': '5uuk',
#  '1.10.439': '1gk9',
#  '1.10.440': '2end',
#  '1.10.441': '2wfp',
#  '1.10.442': '5b1a',
#  '1.10.443': '1xo0',
#  '1.10.455': '1iqv',
#  '1.10.460': '1mw9',
#  '1.10.468': '2wjn',
#  '1.10.470': '2vsg',
#  '1.10.472': '2i53',
#  '1.10.486': '3lfu',
#  '1.10.489': '6ekz',
#  '1.10.490': '5yce',
#  '1.10.506': '3fay',
#  '1.10.510': '5nkf',
#  '1.10.520': '4bll',
#  '1.10.530': '2vb1',
#  '1.10.532': '1bgf',
#  '1.10.533': '1cy5',
#  '1.10.540': '2uxw',
#  '1.10.555': '2ovj',
#  '1.10.560': '1sx3',
#  '1.10.565': '1ymt',
#  '1.10.569': '4z3x',
#  '1.10.575': '5fbf',
#  '1.10.579': '5zm0',
#  '1.10.580': '2ibp',
#  '1.10.590': '5w6y',
#  '1.10.599': '1b25',
#  '1.10.600': '1wmw',
#  '1.10.601': '1sig',
#  '1.10.606': '1qi9',
#  '1.10.620': '1mxr',
#  '1.10.630': '1jfb',
#  '1.10.640': '5mfa',
#  '1.10.645': '4u9h',
#  '1.10.700': '3wrb',
#  '1.10.720': '1jeq',
#  '1.10.730': '4qre',
#  '1.10.740': '1mus',
#  '1.10.750': '2c9w',
#  '1.10.760': '3ziy',
#  '1.10.780': '4fas',
#  '1.10.790': '3o79',
#  '1.10.800': '1j8u',
#  '1.10.820': '1hei',
#  '1.10.840': '6d55',
#  '1.10.860': '6cbr',
#  '1.10.870': '1iie',
#  '1.10.880': '1skn',
#  '1.10.890': '5wkr',
#  '1.10.930': '2oq1',
#  '1.10.940': '3d3b',
#  '1.10.950': '1yu5',
#  '1.10.1000': '1xsz',
#  '1.10.1020': '2g1p',
#  '1.10.1030': '1a9x',
#  '1.10.1040': '1evy',
#  '1.10.1050': '2vqe',
#  '1.10.1060': '2h88',
#  '1.10.1070': '2wxf',
#  '1.10.1080': '3kal',
#  '1.10.1090': '2fyu',
#  '1.10.1100': '1tba',
#  '1.10.1130': '3bnj',
#  '1.10.1140': '2ck3',
#  '1.10.1160': '2ja2',
#  '1.10.1170': '4hy4',
#  '1.10.1180': '1f6v',
#  '1.10.1200': '4bpf',
#  '1.10.1220': '1irq',
#  '1.10.1240': '4jgi',
#  '1.10.1270': '4yqa',
#  '1.10.1280': '5z0f',
#  '1.10.1290': '16vp',
#  '1.10.1300': '1tbf',
#  '1.10.1320': '1msw',
#  '1.10.1330': '5nrm',
#  '1.10.1350': '1qhd',
#  '1.10.1370': '3ahn',
#  '1.10.1380': '6gid',
#  '1.10.1390': '2cxn',
#  '1.10.1400': '1gk9',
#  '1.10.1410': '4ud4',
#  '1.10.1420': '1wb9',
#  '1.10.1440': '1i5j',
#  '1.10.1450': '5m33',
#  '1.10.1470': '4z49',
#  '1.10.1490': '1iyr',
#  '1.10.1500': '2pby',
#  '1.10.1510': '5yrv',
#  '1.10.1520': '3o2r',
#  '1.10.1530': '1wtj',
#  '1.10.1540': '1t77',
#  '1.10.1580': '3cnl',
#  '1.10.1600': '1jey',
#  '1.10.1610': '4kqk',
#  '1.10.1620': '2v7q',
#  '1.10.1630': '1zoq',
#  '1.10.1650': '1vq8',
#  '1.10.1660': '1q08',
#  '1.10.1670': '2xhi',
#  '1.10.1710': '3mw6',
#  '1.10.1720': '1e5r',
#  '1.10.1740': '4lup',
#  '1.10.1750': '3pvv',
#  '1.10.1760': '3rlb',
#  '1.10.1780': '3wdc',
#  '1.10.1790': '3nuf',
#  '1.10.1810': '1tkv',
#  '1.10.1820': '1qf8',
#  '1.10.1840': '5c5o',
#  '1.10.1850': '1tx9',
#  '1.10.1870': '2axq',
#  '1.10.1900': '3kuj',
#  '1.10.2000': '1ijy',
#  '1.10.2010': '1j0t',
#  '1.10.2020': '2qee',
#  '1.10.2030': '4pkw',
#  '1.10.2040': '1jmu',
#  '1.10.2050': '1jmu',
#  '1.10.2060': '1k87',
#  '1.10.2080': '1n8v',
#  '1.10.2090': '5tux',
#  '1.10.3020': '3i2k',
#  '1.10.3030': '1n81',
#  '1.10.3040': '1n93',
#  '1.10.3050': '1n93',
#  '1.10.3060': '2fsi',
#  '1.10.3070': '1nxh',
#  '1.10.3080': '4ene',
#  '1.10.3090': '4wby',
#  '1.10.3100': '2ox6',
#  '1.10.3110': '3lov',
#  '1.10.3120': '2nsa',
#  '1.10.3130': '3q1x',
#  '1.10.3140': '1u8v',
#  '1.10.3160': '4b2f',
#  '1.10.3170': '1w36',
#  '1.10.3180': '4zds',
#  '1.10.3190': '1wpb',
#  '1.10.3200': '4y97',
#  '1.10.3210': '3m1t',
#  '1.10.3230': '1vt0',
#  '1.10.3250': '1wte',
#  '1.10.3260': '2cfm',
#  '1.10.3270': '2r4f',
#  '1.10.3280': '1kyq',
#  '1.10.3290': '5ckl',
#  '1.10.3300': '3h0n',
#  '1.10.3320': '2gvi',
#  '1.10.3330': '3o7i',
#  '1.10.3340': '3fyb',
#  '1.10.3350': '4u12',
#  '1.10.3360': '2p3y',
#  '1.10.3370': '5aww',
#  '1.10.3380': '2zj8',
#  '1.10.3390': '2oa5',
#  '1.10.3400': '2ph7',
#  '1.10.3410': '3bg2',
#  '1.10.3420': '2yf4',
#  '1.10.3430': '3b9w',
#  '1.10.3440': '2pv4',
#  '1.10.3450': '2ijq',
#  '1.10.3460': '2bhw',
#  '1.10.3470': '2nq2',
#  '1.10.3480': '1s9u',
#  '1.10.3490': '2p62',
#  '1.10.3500': '3bzc',
#  '1.10.3510': '2o5h',
#  '1.10.3520': '3rzn',
#  '1.10.3530': '2ijr',
#  '1.10.3540': '3bhw',
#  '1.10.3550': '3bg2',
#  '1.10.3560': '2jyn',
#  '1.10.3570': '3hhw',
#  '1.10.3580': '2r31',
#  '1.10.3590': '2qts',
#  '1.10.3600': '3c4r',
#  '1.10.3610': '3hhw',
#  '1.10.3620': '3ca8',
#  '1.10.3630': '2zih',
#  '1.10.3640': '3c24',
#  '1.10.3650': '1q16',
#  '1.10.3660': '2f1k',
#  '1.10.3670': '4q68',
#  '1.10.3680': '2h5n',
#  '1.10.3690': '2igs',
#  '1.10.3700': '2o8s',
#  '1.10.3710': '2r9g',
#  '1.10.3720': '3rlf',
#  '1.10.3730': '5bse',
#  '1.10.3740': '2i71',
#  '1.10.3750': '1sed',
#  '1.10.3760': '1y9i',
#  '1.10.3780': '3ckc',
#  '1.10.3790': '1pc6',
#  '1.10.3800': '2aua',
#  '1.10.3810': '2oqo',
#  '1.10.3820': '2j7a',
#  '1.10.3830': '2kdc',
#  '1.10.3860': '6r7r',
#  '1.10.3870': '1y8a',
#  '1.10.3880': '1t07',
#  '1.10.3890': '1sdi',
#  '1.10.3900': '2oez',
#  '1.10.3910': '2fi0',
#  '1.10.3920': '2fef',
#  '1.10.3930': '1s9r',
#  '1.10.3940': '3dt5',
#  '1.10.3950': '3fh3',
#  '1.10.3960': '1tm9',
#  '1.10.3970': '1x3a',
#  '1.10.3980': '1vrm',
#  '1.10.3990': '3kk4',
#  '1.10.4000': '1g8e',
#  '1.10.4010': '1w2y',
#  '1.10.4020': '3lhr',
#  '1.10.4030': '3rgc',
#  '1.10.4040': '1sd4',
#  '1.10.4050': '1v4a',
#  '1.10.4060': '1zbo',
#  '1.10.4070': '2o9x',
#  '1.10.4080': '6g1p',
#  '1.10.4090': '5gmz',
#  '1.10.4100': '2hp0',
#  '1.10.4110': '1q5z',
#  '1.10.4120': '1gzs',
#  '1.10.4140': '3nb2',
#  '1.10.4150': '2fm9',
#  '1.10.4160': '2jln',
#  '1.10.4170': '2jo7',
#  '1.10.4180': '2vy1',
#  '1.10.4190': '3cxn',
#  '1.10.4200': '3h9p',
#  '1.20.5': '2ynz',
#  '1.20.10': '1ehs',
#  '1.20.20': '2xqu',
#  '1.20.50': '2jms',
#  '1.20.58': '3edv',
#  '1.20.59': '2d8d',
#  '1.20.80': '6ibe',
#  '1.20.81': '2fcw',
#  '1.20.82': '4cmh',
#  '1.20.85': '1rzh',
#  '1.20.89': '3aek',
#  '1.20.90': '1mc2',
#  '1.20.91': '4p3a',
#  '1.20.120': '4ebj',
#  '1.20.140': '5zw7',
#  '1.20.141': '4olt',
#  '1.20.142': '4zzx',
#  '1.20.144': '3bb0',
#  '1.20.150': '5ii8',
#  '1.20.190': '3x0u',
#  '1.20.200': '1gkm',
#  '1.20.210': '5b1a',
#  '1.20.225': '4rgd',
#  '1.20.245': '4wfo',
#  '1.20.250': '1cii',
#  '1.20.272': '3bge',
#  '1.20.810': '3cx5',
#  '1.20.840': '5a0y',
#  '1.20.850': '4fas',
#  '1.20.860': '1jb0',
#  '1.20.870': '6d55',
#  '1.20.890': '3g36',
#  '1.20.900': '4yon',
#  '1.20.910': '3b5o',
#  '1.20.920': '5ig6',
#  '1.20.930': '3nfq',
#  '1.20.940': '1dvk',
#  '1.20.950': '1kqf',
#  '1.20.960': '4zpc',
#  '1.20.970': '2elc',
#  '1.20.990': '3qfs',
#  '1.20.1000': '1f5n',
#  '1.20.1020': '3t92',
#  '1.20.1050': '4mf5',
#  '1.20.1060': '6fbc',
#  '1.20.1070': '5zim',
#  '1.20.1080': '3zoj',
#  '1.20.1090': '5br4',
#  '1.20.1110': '3ar4',
#  '1.20.1120': '1epw',
#  '1.20.1130': '1jb0',
#  '1.20.1150': '2c0g',
#  '1.20.1160': '4fqn',
#  '1.20.1170': '4phq',
#  '1.20.1180': '4e6u',
#  '1.20.1200': '3ci3',
#  '1.20.1220': '5vfb',
#  '1.20.1230': '1jad',
#  '1.20.1240': '5oy0',
#  '1.20.1250': '2d48',
#  '1.20.1260': '6b8f',
#  '1.20.1270': '2d1l',
#  '1.20.1280': '2e31',
#  '1.20.1290': '2oyo',
#  '1.20.1300': '2h88',
#  '1.20.1310': '2wzk',
#  '1.20.1320': '5jaj',
#  '1.20.1330': '2d4x',
#  '1.20.1340': '3k40',
#  '1.20.1370': '3wky',
#  '1.20.1380': '3sk7',
#  '1.20.1390': '3v53',
#  '1.20.1400': '1t50',
#  '1.20.1410': '1r0d',
#  '1.20.1420': '4w8p',
#  '1.20.1430': '3p0b',
#  '1.20.1440': '2qsb',
#  '1.20.1450': '4phz',
#  '1.20.1460': '3rrk',
#  '1.20.1480': '3vjf',
#  '1.20.1500': '2iaz',
#  '1.20.1510': '3h90',
#  '1.20.1520': '4zi3',
#  '1.20.1530': '4n7w',
#  '1.20.1540': '2xov',
#  '1.20.1550': '2zuq',
#  '1.20.1560': '4a82',
#  '1.20.1570': '3bh1',
#  '1.20.1580': '2vf7',
#  '1.20.1590': '2q9r',
#  '1.20.1600': '5azp',
#  '1.20.1610': '2ww2',
#  '1.20.1630': '2vpz',
#  '1.20.1640': '4dx5',
#  '1.20.1650': '2qma',
#  '1.20.1660': '2b6c',
#  '1.20.1670': '4dk2',
#  '1.20.1680': '4dk2',
#  '1.20.1690': '3s6p',
#  '1.20.1700': '1q16',
#  '1.20.1710': '3nft',
#  '1.20.1720': '2gfp',
#  '1.20.1730': '3dh4',
#  '1.20.1740': '3gia',
#  '1.25.10': '4uaf',
#  '1.25.20': '1qsa',
#  '1.25.40': '3ro3',
#  '1.25.50': '6q4r',
#  '1.25.60': '2oux',
#  '1.25.70': '3m66',
#  '1.40.10': '3iis',
#  '1.40.20': '6qv7',
#  '1.50.10': '4ayo',
#  '1.50.40': '1okc',
#  '2.10.10': '1h8p',
#  '2.10.22': '1bx7',
#  '2.10.25': '3sov',
#  '2.10.50': '3wvt',
#  '2.10.55': '1lml',
#  '2.10.60': '2j8b',
#  '2.10.69': '2fj8',
#  '2.10.70': '4k12',
#  '2.10.77': '3ku3',
#  '2.10.80': '1lpb',
#  '2.10.90': '1mkk',
#  '2.10.109': '3k2z',
#  '2.10.110': '4hi8',
#  '2.10.150': '4gy7',
#  '2.10.160': '4deq',
#  '2.10.210': '1ppj',
#  '2.10.220': '4c9r',
#  '2.10.230': '1nlt',
#  '2.10.240': '1ep3',
#  '2.10.250': '1jhn',
#  '2.10.260': '5itm',
#  '2.10.270': '2f6e',
#  '2.10.280': '1h6w',
#  '2.10.290': '2jne',
#  '2.10.300': '1uun',
#  '2.10.310': '1qmb',
#  '2.20.20': '4gv5',
#  '2.20.25': '6d9n',
#  '2.20.28': '2dsx',
#  '2.20.50': '1lsh',
#  '2.20.60': '1mkn',
#  '2.20.70': '1pin',
#  '2.20.80': '1lsh',
#  '2.20.90': '1lsh',
#  '2.20.100': '6b0s',
#  '2.20.110': '3m58',
#  '2.20.120': '2j8g',
#  '2.20.130': '3hrz',
#  '2.20.140': '2ra8',
#  '2.20.150': '3pl2',
#  '2.20.160': '1ya5',
#  '2.20.170': '3bxj',
#  '2.20.180': '2r01',
#  '2.20.200': '5azp',
#  '2.20.210': '6c6z',
#  '2.20.220': '3pqh',
#  '2.20.230': '3eo5',
#  '2.30.18': '1nh2',
#  '2.30.22': '1dkg',
#  '2.30.24': '3rio',
#  '2.30.26': '2e6f',
#  '2.30.27': '1g3p',
#  '2.30.29': '1unq',
#  '2.30.30': '2o9s',
#  '2.30.31': '2it9',
#  '2.30.32': '1e8r',
#  '2.30.33': '1g31',
#  '2.30.34': '1lml',
#  '2.30.36': '2pbd',
#  '2.30.38': '2d1s',
#  '2.30.39': '5c98',
#  '2.30.40': '1ra0',
#  '2.30.42': '4z8j',
#  '2.30.60': '2rdk',
#  '2.30.90': '1mkc',
#  '2.30.110': '2r0x',
#  '2.30.120': '1gk9',
#  '2.30.130': '3d79',
#  '2.30.140': '2i7c',
#  '2.30.150': '2a6h',
#  '2.30.160': '1fjr',
#  '2.30.170': '5dm6',
#  '2.30.180': '1o70',
#  '2.30.210': '2v0c',
#  '2.30.220': '1io1',
#  '2.30.230': '1lsh',
#  '2.30.240': '1ydu',
#  '2.30.250': '5jgf',
#  '2.30.260': '4q68',
#  '2.30.270': '2ra9',
#  '2.30.280': '3fde',
#  '2.30.290': '5dmd',
#  '2.30.300': '1wru',
#  '2.30.310': '5h3x',
#  '2.30.320': '1pv5',
#  '2.30.330': '4yx1',
#  '2.30.340': '1yvu',
#  '2.40.10': '5avd',
#  '2.40.15': '1a1x',
#  '2.40.20': '6dcm',
#  '2.40.30': '3w5h',
#  '2.40.33': '2g50',
#  '2.40.37': '1rcq',
#  '2.40.40': '1pqh',
#  '2.40.50': '1x54',
#  '2.40.70': '1bxo',
#  '2.40.100': '4o8h',
#  '2.40.110': '5zw7',
#  '2.40.128': '3kff',
#  '2.40.150': '1whi',
#  '2.40.155': '6jgj',
#  '2.40.160': '5fvn',
#  '2.40.170': '5fok',
#  '2.40.180': '3ttv',
#  '2.40.200': '1jb7',
#  '2.40.220': '4xjw',
#  '2.40.230': '1qd5',
#  '2.40.240': '3aii',
#  '2.40.250': '3wtt',
#  '2.40.260': '2w1j',
#  '2.40.270': '1twf',
#  '2.40.280': '1wjx',
#  '2.40.290': '1ow1',
#  '2.40.300': '1c5e',
#  '2.40.310': '1nyc',
#  '2.40.320': '5a67',
#  '2.40.330': '4i1k',
#  '2.40.340': '6fgd',
#  '2.40.350': '2q03',
#  '2.40.360': '2in5',
#  '2.40.370': '2ich',
#  '2.40.380': '3exm',
#  '2.40.390': '2o3i',
#  '2.40.400': '4zbo',
#  '2.40.410': '3c8i',
#  '2.40.420': '4l8j',
#  '2.40.430': '3rlf',
#  '2.40.440': '6d4k',
#  '2.40.450': '2gmq',
#  '2.40.460': '4wz8',
#  '2.40.470': '1ye9',
#  '2.40.480': '4h6c',
#  '2.40.490': '4gip',
#  '2.40.500': '1h5w',
#  '2.40.510': '4oox',
#  '2.50.10': '3eoj',
#  '2.50.20': '4mxt',
#  '2.60.9': '2hnu',
#  '2.60.11': '5b1a',
#  '2.60.15': '2e5y',
#  '2.60.20': '4iau',
#  '2.60.30': '2oiz',
#  '2.60.34': '4f01',
#  '2.60.40': '4unu',
#  '2.60.60': '4wfo',
#  '2.60.90': '6fjn',
#  '2.60.98': '1svb',
#  '2.60.110': '5x9l',
#  '2.60.120': '5k8s',
#  '2.60.130': '4whs',
#  '2.60.169': '2bpa',
#  '2.60.175': '4mby',
#  '2.60.200': '2pie',
#  '2.60.210': '4ysi',
#  '2.60.220': '1rwh',
#  '2.60.240': '1cq3',
#  '2.60.250': '1p35',
#  '2.60.260': '3tj8',
#  '2.60.270': '4wdc',
#  '2.60.290': '1nc7',
#  '2.60.300': '1r94',
#  '2.60.310': '1js8',
#  '2.60.320': '3ld7',
#  '2.60.330': '1n7v',
#  '2.60.340': '1n7z',
#  '2.60.350': '1x0c',
#  '2.60.370': '1so9',
#  '2.60.390': '3og2',
#  '2.60.410': '3mzf',
#  '2.60.420': '1v7w',
#  '2.60.430': '2p84',
#  '2.60.440': '2oez',
#  '2.60.450': '2r19',
#  '2.60.460': '2qzb',
#  '2.60.470': '2qts',
#  '2.60.480': '3g74',
#  '2.60.490': '5svk',
#  '2.60.500': '1ywm',
#  '2.60.510': '1gku',
#  '2.60.520': '1zru',
#  '2.60.530': '3iox',
#  '2.70.9': '2obe',
#  '2.70.10': '2pw8',
#  '2.70.20': '1mw9',
#  '2.70.40': '1euw',
#  '2.70.50': '4eir',
#  '2.70.70': '4qp5',
#  '2.70.98': '1rwh',
#  '2.70.100': '2v3i',
#  '2.70.130': '1gp0',
#  '2.70.150': '3ar4',
#  '2.70.160': '4c08',
#  '2.70.170': '2wn9',
#  '2.70.180': '1njh',
#  '2.70.210': '5m04',
#  '2.70.220': '2ag4',
#  '2.70.230': '3w9e',
#  '2.70.240': '4iya',
#  '2.70.250': '1n7v',
#  '2.80.10': '3nbc',
#  '2.80.20': '1yu0',
#  '2.90.10': '2dpf',
#  '2.90.20': '6b0g',
#  '2.100.10': '3ll2',
#  '2.102.10': '2bmo',
#  '2.102.20': '3og2',
#  '2.102.30': '3dcl',
#  '2.105.10': '1n7v',
#  '2.110.10': '3c7x',
#  '2.115.10': '4n1i',
#  '2.120.10': '1pjx',
#  '2.130.10': '2oiz',
#  '2.140.10': '4a5s',
#  '2.150.10': '5d7w',
#  '2.160.10': '3kwd',
#  '2.160.20': '1k5c',
#  '2.160.30': '1h6w',
#  '2.170.8': '4gmu',
#  '2.170.9': '2obe',
#  '2.170.11': '1ois',
#  '2.170.14': '2xc1',
#  '2.170.15': '2d42',
#  '2.170.16': '6fre',
#  '2.170.30': '3ng9',
#  '2.170.40': '4jzz',
#  '2.170.120': '2pa8',
#  '2.170.130': '1kmo',
#  '2.170.140': '1dqc',
#  '2.170.150': '5amh',
#  '2.170.160': '5yj6',
#  '2.170.170': '3s9z',
#  '2.170.180': '1fjr',
#  '2.170.190': '6fgc',
#  '2.170.200': '2nnu',
#  '2.170.210': '2y3v',
#  '2.170.220': '2d5b',
#  '2.170.230': '1b12',
#  '2.170.240': '1t60',
#  '2.170.260': '4z4d',
#  '2.170.270': '3f9x',
#  '2.170.280': '1io1',
#  '2.170.290': '1n7z',
#  '2.170.300': '2gy5',
#  '2.180.10': '5kis',
#  '3.10.10': '4g1q',
#  '3.10.20': '3goe',
#  '3.10.25': '2bln',
#  '3.10.28': '2ab5',
#  '3.10.40': '3g4n',
#  '3.10.50': '2y78',
#  '3.10.100': '3wh3',
#  '3.10.105': '1jet',
#  '3.10.110': '1z2u',
#  '3.10.120': '3x34',
#  '3.10.129': '4mtu',
#  '3.10.130': '1dy5',
#  '3.10.150': '4k3l',
#  '3.10.170': '5jvi',
#  '3.10.180': '1nki',
#  '3.10.196': '6bdy',
#  '3.10.200': '3ks3',
#  '3.10.250': '1z8g',
#  '3.10.260': '1l8r',
#  '3.10.270': '3l8w',
#  '3.10.280': '3jv1',
#  '3.10.290': '1dm9',
#  '3.10.300': '3uby',
#  '3.10.310': '4jbd',
#  '3.10.320': '4x5w',
#  '3.10.330': '5b6c',
#  '3.10.340': '4gvq',
#  '3.10.350': '5k2l',
#  '3.10.360': '1fd3',
#  '3.10.380': '2b5u',
#  '3.10.390': '1oqj',
#  '3.10.400': '1r6x',
#  '3.10.410': '3do6',
#  '3.10.420': '2hng',
#  '3.10.430': '1div',
#  '3.10.440': '1vq8',
#  '3.10.450': '6c1x',
#  '3.10.460': '2w2s',
#  '3.10.470': '1t23',
#  '3.10.490': '3jud',
#  '3.10.500': '1x9y',
#  '3.10.510': '2h7a',
#  '3.10.520': '4xdu',
#  '3.10.530': '2jov',
#  '3.10.540': '2ra9',
#  '3.10.550': '2hly',
#  '3.10.560': '2j58',
#  '3.10.570': '3ib5',
#  '3.10.580': '2uv4',
#  '3.10.590': '2hd9',
#  '3.10.600': '2qf7',
#  '3.10.610': '3ci0',
#  '3.10.620': '2zk9',
#  '3.10.630': '3bh1',
#  '3.10.640': '2g3w',
#  '3.10.650': '3rlf',
#  '3.10.660': '4x33',
#  '3.10.670': '4g29',
#  '3.10.680': '5b66',
#  '3.10.690': '1vjl',
#  '3.15.10': '1ewf',
#  '3.15.20': '1ewf',
#  '3.15.30': '3bqw',
#  '3.20.10': '2eiy',
#  '3.20.14': '3a9s',
#  '3.20.16': '4p3h',
#  '3.20.19': '3h5j',
#  '3.20.20': '2vxn',
#  '3.20.70': '3o0q',
#  '3.20.80': '3r8j',
#  '3.20.90': '3c5n',
#  '3.20.100': '3bgy',
#  '3.20.110': '3bvx',
#  '3.20.120': '2b97',
#  '3.20.130': '2isb',
#  '3.20.140': '3os4',
#  '3.20.160': '2qhq',
#  '3.20.170': '2o0q',
#  '3.20.180': '2arz',
#  '3.20.190': '1k3x',
#  '3.20.200': '3lkm',
#  '3.30.9': '3nyc',
#  '3.30.10': '5e10',
#  '3.30.20': '3wh1',
#  '3.30.30': '3psm',
#  '3.30.40': '3t7l',
#  '3.30.43': '1zr6',
#  '3.30.44': '1kvd',
#  '3.30.46': '3thr',
#  '3.30.50': '3fyl',
#  '3.30.54': '1v4p',
#  '3.30.56': '2cxi',
#  '3.30.60': '1r0r',
#  '3.30.62': '4u5w',
#  '3.30.63': '1kgd',
#  '3.30.65': '1yua',
#  '3.30.66': '2f4q',
#  '3.30.67': '5jhm',
#  '3.30.70': '6n3d',
#  '3.30.110': '3hz7',
#  '3.30.160': '4gzn',
#  '3.30.170': '1cks',
#  '3.30.190': '4reo',
#  '3.30.200': '6hmq',
#  '3.30.210': '3b0x',
#  '3.30.230': '1nz0',
#  '3.30.240': '4xr8',
#  '3.30.250': '5jrj',
#  '3.30.260': '1kp8',
#  '3.30.280': '5ol4',
#  '3.30.300': '6d9n',
#  '3.30.305': '2hdi',
#  '3.30.310': '3na5',
#  '3.30.342': '3qex',
#  '3.30.350': '2sic',
#  '3.30.360': '6gg7',
#  '3.30.365': '4usa',
#  '3.30.370': '5f4c',
#  '3.30.379': '1gqi',
#  '3.30.380': '2qud',
#  '3.30.386': '4olt',
#  '3.30.387': '4gsx',
#  '3.30.390': '1r0m',
#  '3.30.410': '1ju2',
#  '3.30.412': '3g4n',
#  '3.30.413': '6c3m',
#  '3.30.420': '3i33',
#  '3.30.428': '3ohe',
#  '3.30.429': '3b64',
#  '3.30.430': '3a2e',
#  '3.30.450': '1nwz',
#  '3.30.457': '3vz9',
#  '3.30.460': '3hj4',
#  '3.30.465': '2vfr',
#  '3.30.470': '1kjq',
#  '3.30.479': '3d7j',
#  '3.30.497': '6hgm',
#  '3.30.499': '1c96',
#  '3.30.500': '1k5n',
#  '3.30.505': '5gji',
#  '3.30.519': '1d5t',
#  '3.30.530': '4bk7',
#  '3.30.540': '5iz3',
#  '3.30.559': '2rkv',
#  '3.30.560': '3qvp',
#  '3.30.565': '5cph',
#  '3.30.572': '6nnr',
#  '3.30.590': '1m15',
#  '3.30.700': '1x6z',
#  '3.30.710': '4bgc',
#  '3.30.720': '1u7i',
#  '3.30.730': '2kvt',
#  '3.30.740': '2xqq',
#  '3.30.750': '1h4x',
#  '3.30.760': '4ue8',
#  '3.30.780': '5zcy',
#  '3.30.800': '3x01',
#  '3.30.810': '3x01',
#  '3.30.830': '3go9',
#  '3.30.860': '3a1p',
#  '3.30.870': '1v0u',
#  '3.30.890': '6c1t',
#  '3.30.900': '5c50',
#  '3.30.910': '1u2m',
#  '3.30.920': '1whz',
#  '3.30.930': '4xem',
#  '3.30.950': '2z6r',
#  '3.30.960': '3agk',
#  '3.30.980': '1v4p',
#  '3.30.990': '1qd1',
#  '3.30.1010': '4uwh',
#  '3.30.1020': '3a2v',
#  '3.30.1030': '4gvq',
#  '3.30.1040': '4hsc',
#  '3.30.1050': '1pz4',
#  '3.30.1060': '4gwb',
#  '3.30.1070': '3ku7',
#  '3.30.1110': '2abs',
#  '3.30.1120': '1hdh',
#  '3.30.1130': '2o90',
#  '3.30.1140': '2vqe',
#  '3.30.1150': '4g7x',
#  '3.30.1160': '1dw9',
#  '3.30.1170': '1gax',
#  '3.30.1180': '4x9x',
#  '3.30.1190': '1nr3',
#  '3.30.1200': '1n91',
#  '3.30.1220': '1nij',
#  '3.30.1230': '6az1',
#  '3.30.1240': '2rbk',
#  '3.30.1250': '2wbm',
#  '3.30.1280': '2zw2',
#  '3.30.1300': '5bw0',
#  '3.30.1310': '1j8b',
#  '3.30.1320': '3bn0',
#  '3.30.1330': '1xbi',
#  '3.30.1340': '3ccd',
#  '3.30.1350': '1ejg',
#  '3.30.1360': '1xpp',
#  '3.30.1370': '1zzk',
#  '3.30.1380': '3k7i',
#  '3.30.1390': '3dnj',
#  '3.30.1400': '1f46',
#  '3.30.1410': '1jg5',
#  '3.30.1420': '1sau',
#  '3.30.1430': '1vq8',
#  '3.30.1440': '1iq4',
#  '3.30.1450': '3d4e',
#  '3.30.1460': '4g6t',
#  '3.30.1470': '1jb0',
#  '3.30.1480': '1k0r',
#  '3.30.1490': '1kjq',
#  '3.30.1500': '4o6u',
#  '3.30.1510': '3do6',
#  '3.30.1520': '1kq6',
#  '3.30.1530': '1o9i',
#  '3.30.1540': '2yim',
#  '3.30.1550': '3cjs',
#  '3.30.1560': '1oo0',
#  '3.30.1570': '1huf',
#  '3.30.1580': '2l6q',
#  '3.30.1590': '3hje',
#  '3.30.1600': '4bn4',
#  '3.30.1610': '5hb6',
#  '3.30.1620': '1l1l',
#  '3.30.1640': '4ywk',
#  '3.30.1650': '1oao',
#  '3.30.1660': '2ux9',
#  '3.30.1670': '1okg',
#  '3.30.1680': '4wk0',
#  '3.30.1690': '3vor',
#  '3.30.1700': '3p3e',
#  '3.30.1710': '1qys',
#  '3.30.1730': '1t8s',
#  '3.30.1740': '3od8',
#  '3.30.1750': '1vcl',
#  '3.30.1760': '1vk1',
#  '3.30.1770': '2py5',
#  '3.30.1780': '1x7d',
#  '3.30.1790': '1td6',
#  '3.30.1810': '2hh8',
#  '3.30.1820': '2iay',
#  '3.30.1830': '2joe',
#  '3.30.1840': '1xdp',
#  '3.30.1850': '3bq9',
#  '3.30.1860': '2qya',
#  '3.30.1870': '2qgm',
#  '3.30.1880': '5z0f',
#  '3.30.1890': '4e29',
#  '3.30.1900': '3f2b',
#  '3.30.1910': '4zya',
#  '3.30.1920': '3cdd',
#  '3.30.1930': '3bqw',
#  '3.30.1940': '3bu2',
#  '3.30.1950': '2j58',
#  '3.30.1960': '2it2',
#  '3.30.1970': '2fdo',
#  '3.30.1980': '1qw2',
#  '3.30.1990': '1sr8',
#  '3.30.2000': '4acv',
#  '3.30.2010': '4jiu',
#  '3.30.2020': '3k8r',
#  '3.30.2030': '2v7s',
#  '3.30.2040': '2pif',
#  '3.30.2050': '5b66',
#  '3.30.2060': '3fpn',
#  '3.30.2070': '2vpz',
#  '3.30.2080': '2ww2',
#  '3.30.2090': '4dx5',
#  '3.30.2110': '1sr8',
#  '3.30.2120': '1r7l',
#  '3.30.2130': '1zhv',
#  '3.30.2140': '1w5r',
#  '3.30.2150': '1nt2',
#  '3.30.2160': '3h1d',
#  '3.30.2170': '3goc',
#  '3.30.2180': '2r31',
#  '3.30.2190': '2guk',
#  '3.30.2200': '3fn2',
#  '3.30.2210': '3fy6',
#  '3.30.2220': '3fgx',
#  '3.30.2230': '4a3p',
#  '3.30.2240': '3bl9',
#  '3.30.2250': '1ro2',
#  '3.30.2260': '2nml',
#  '3.30.2270': '2gag',
#  '3.30.2280': '1sgo',
#  '3.30.2290': '5nj9',
#  '3.30.2300': '1vbk',
#  '3.30.2310': '4ltt',
#  '3.30.2320': '2pk8',
#  '3.30.2330': '3it4',
#  '3.30.2340': '1szw',
#  '3.30.2350': '4lgt',
#  '3.30.2360': '1p1h',
#  '3.30.2370': '3ic3',
#  '3.30.2380': '4ww7',
#  '3.30.2390': '4kk7',
#  '3.30.2400': '3dkt',
#  '3.30.2410': '3h1d',
#  '3.30.2420': '1u07',
#  '3.30.2430': '3bo6',
#  '3.30.2440': '3cxb',
#  '3.30.2450': '2lez',
#  ...}

# %% [markdown]
# The following is an example of how to access the UniProt code using the PDB code

# %% [markdown]
# It is necessary to create a third dictionary that links the CATH code with the UniProt code. To obtain the UniProt code we will access the RCSB PDB web page of each protein. It will be necessary to use the following url:
# * https://www.rcsb.org/structure/protein_code_pdb

# %%
def update_pdb_code(code_pdb,result):

    while result== None: 
        url="https://www.rcsb.org/structure/" + code_pdb
        #print(url)
        page= requests.get(url)
        soup= BeautifulSoup(page.content,'html.parser')
        result= soup.find("li",{"id":"note_obsoletedBy"})
        if result!=None:
            #print(result)
            dirty_code=result.text
            #print(dirty_code)
            code_pdb=dirty_code[-5:-1]
            url="https://www.rcsb.org/structure/" + code_pdb
            #print(url)
            page= requests.get(url)
            soup= BeautifulSoup(page.content,'html.parser')
            result= soup.find("div",{"class":"col-lg-2 col-md-2 text-right"})
            #print(result)
        else:
            #print("there is no UniProt code for this protein")
            code_UniProt="there is no UniProt code for this protein"
            #print(result)
            break

    if result!=None:
        #print(dirty_code)
        dirty_code=result.text
        v=dirty_code.find(":")
        code_UniProt=dirty_code[v+3:]
    return(code_pdb,code_UniProt)

def find_UniProt_code(dic_pdb):
    from bs4 import BeautifulSoup
    dic_UniProt={}

    for k in dic_pdb:
        code_pdb=dic_pdb[k]
        url="https://www.rcsb.org/structure/" + code_pdb
        #print(url)
        page= requests.get(url)
        soup= BeautifulSoup(page.content,'html.parser')
        try:
            result= soup.find("div",{"class":"col-lg-2 col-md-2 text-right"})
            dirty_code=result.text
            v=dirty_code.find(":")
            code=dirty_code[v+3:]
            dic_UniProt[code_pdb]=code
            #print(code)
        except AttributeError:
            (code_PDB,code)=update_pdb_code(code_pdb,result)    #this function allows to find the updates of the pdb codes and thus to obtain the corresponding UniProt code.
            dic_UniProt[code_PDB]=code
            dic_pdb[k]=code_PDB # +"nnn"    #3 characters are added because all the pdb codes in the dictionary contain them (this problem will be solved later).
    return(dic_UniProt)

# %%
def write_file(fileName,dic):
    file = open(fileName, "w")
    json.dump(dic, file)
    file.close()
def read_file2(fileName):
    with open(fileName, 'r') as f:
        json_data = json.load(f)
    return(json_data)

if os.path.exists("dic_UniProt.json")==False:       #if the file with the UniProt dictionary information already exists, it does not execute the code.
    dic_UniProt=find_UniProt_code(dic_pdb)
    write_file("dic_UniProt.json",dic_UniProt)
else:
    dic_UniProt=read_file2("dic_UniProt.json")

# %% [markdown]
# ---

# %% [markdown]
# ### We proceed to extract the data from the pdb and AlphaFold web

# %% [markdown]
# We will need the following links, where they will be completed with the program:
#
# * url: https://files.rcsb.org/view/CodePDB.pdb
# * url: https://alphafold.ebi.ac.uk/files/AF-CodeUniProt-F1-predicted_aligned_error_v2.json
# * url: https://alphafold.ebi.ac.uk/files/AF-CodeUniProt-F1-model_v2.pdb

# %% [markdown]
# We will use the dictionary created earlier.

# %%
os.chdir(RCSB_pdb)

# %%
#### In process
def download_file(dic,dic2,n):
    for k in dic:
        if k.count(".")==n:
            pdb=dic[k]#[:-3]
            print(dic[k])
            if pdb in dic2:

                CodeUniProt=dic2[pdb]
                print(CodeUniProt)

                code_PDB=pdb+".pdb"
                url_pdb='https://files.rcsb.org/view/' + code_PDB
                
                code_file= 'AF-' + CodeUniProt + '-F1-predicted_aligned_error_v2.json'
                url_file='https://alphafold.ebi.ac.uk/files/' + code_file
                print(url_file)

                code_AlphaFold="AF-" + CodeUniProt + "-F1-model_v2.pdb"
                url_AlphaFold_pdb="https://alphafold.ebi.ac.uk/files/" + code_AlphaFold
                print(url_AlphaFold_pdb)

                try:
                    if os.path.exists(code_PDB)==False:
                        file_name=wget.download(url_pdb)
                    
                    if os.path.exists(code_file)==False:
                        file_name=wget.download(url_file)
                    
                    if os.path.exists(code_AlphaFold)==False:
                        file_name=wget.download(url_AlphaFold_pdb)
                except:
                    print("codi no executat a Alphafold")

v=variable.lower()
if v=="yes":
    n=3 # download the complete database, in this case the information of 6631 proteins is downloaded.
else:
    n=1 # download the test database, in this case the information of 43 proteins is downloaded.

download_file(dic_pdb,dic_UniProt,n)
# Out:
# 1xmkA00
# P55265
# https://alphafold.ebi.ac.uk/files/AF-P55265-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-P55265-F1-model_v2.pdb
# 2ynzC01
# P03069
# https://alphafold.ebi.ac.uk/files/AF-P03069-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-P03069-F1-model_v2.pdb
# 3ro3A00
# Q8VDU0
# https://alphafold.ebi.ac.uk/files/AF-Q8VDU0-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-Q8VDU0-F1-model_v2.pdb
# 3iisM00
# P80484
# https://alphafold.ebi.ac.uk/files/AF-P80484-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-P80484-F1-model_v2.pdb
# 4ayoA00
# B0SWV2
# https://alphafold.ebi.ac.uk/files/AF-B0SWV2-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-B0SWV2-F1-model_v2.pdb
# codi no executat a Alphafold
# 3sovA02
# O75581
# https://alphafold.ebi.ac.uk/files/AF-O75581-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-O75581-F1-model_v2.pdb
# 6d9nB01
# A0A077EDR1
# https://alphafold.ebi.ac.uk/files/AF-A0A077EDR1-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-A0A077EDR1-F1-model_v2.pdb
# codi no executat a Alphafold
# 2o9sA00
# Q9BX66
# https://alphafold.ebi.ac.uk/files/AF-Q9BX66-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-Q9BX66-F1-model_v2.pdb
# 1x54A01
# O57980
# https://alphafold.ebi.ac.uk/files/AF-O57980-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-O57980-F1-model_v2.pdb
# 4mxtA00
# A7VAU1
# https://alphafold.ebi.ac.uk/files/AF-A7VAU1-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-A7VAU1-F1-model_v2.pdb
# codi no executat a Alphafold
# 4unuA00
# P01709
# https://alphafold.ebi.ac.uk/files/AF-P01709-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-P01709-F1-model_v2.pdb
# 1rwhA02
# P84141
# https://alphafold.ebi.ac.uk/files/AF-P84141-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-P84141-F1-model_v2.pdb
# codi no executat a Alphafold
# 3nbcA00
# B2ZRS9
# https://alphafold.ebi.ac.uk/files/AF-B2ZRS9-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-B2ZRS9-F1-model_v2.pdb
# 2dpfA00
# P19667
# https://alphafold.ebi.ac.uk/files/AF-P19667-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-P19667-F1-model_v2.pdb
# 3ll2A00
# P84801
# https://alphafold.ebi.ac.uk/files/AF-P84801-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-P84801-F1-model_v2.pdb
# codi no executat a Alphafold
# 2bmoA02
# Q8RTL4
# https://alphafold.ebi.ac.uk/files/AF-Q8RTL4-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-Q8RTL4-F1-model_v2.pdb
# codi no executat a Alphafold
# 1n7vA01
# P27378
# https://alphafold.ebi.ac.uk/files/AF-P27378-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-P27378-F1-model_v2.pdb
# codi no executat a Alphafold
# 3c7xA00
# P50281
# https://alphafold.ebi.ac.uk/files/AF-P50281-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-P50281-F1-model_v2.pdb
# 4n1i
# 1pjxA00
# Q7SIG4
# https://alphafold.ebi.ac.uk/files/AF-Q7SIG4-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-Q7SIG4-F1-model_v2.pdb
# 2oizA01
# P84887
# https://alphafold.ebi.ac.uk/files/AF-P84887-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-P84887-F1-model_v2.pdb
# 4a5sA02
# P27487
# https://alphafold.ebi.ac.uk/files/AF-P27487-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-P27487-F1-model_v2.pdb
# 5d7wA01
# P23694
# https://alphafold.ebi.ac.uk/files/AF-P23694-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-P23694-F1-model_v2.pdb
# 1k5cA00
# P79074
# https://alphafold.ebi.ac.uk/files/AF-P79074-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-P79074-F1-model_v2.pdb
# codi no executat a Alphafold
# 3f9xD00
# Q9NQR1
# https://alphafold.ebi.ac.uk/files/AF-Q9NQR1-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-Q9NQR1-F1-model_v2.pdb
# 5kisB00
# B6A880
# https://alphafold.ebi.ac.uk/files/AF-B6A880-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-B6A880-F1-model_v2.pdb
# 3goeA00
# Q9USX3
# https://alphafold.ebi.ac.uk/files/AF-Q9USX3-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-Q9USX3-F1-model_v2.pdb
# 1ewfA01
# P17213
# https://alphafold.ebi.ac.uk/files/AF-P17213-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-P17213-F1-model_v2.pdb
# 2vxnA00
# P48499
# https://alphafold.ebi.ac.uk/files/AF-P48499-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-P48499-F1-model_v2.pdb
# 6n3dA01
# O43719
# https://alphafold.ebi.ac.uk/files/AF-O43719-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-O43719-F1-model_v2.pdb
# 1hdoA00
# P30043
# https://alphafold.ebi.ac.uk/files/AF-P30043-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-P30043-F1-model_v2.pdb
# 1lqtB02
# P9WIQ3
# https://alphafold.ebi.ac.uk/files/AF-P9WIQ3-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-P9WIQ3-F1-model_v2.pdb
# 4jtmA00
# E3PJ86
# https://alphafold.ebi.ac.uk/files/AF-E3PJ86-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-E3PJ86-F1-model_v2.pdb
# 5xp6A00
# C7C422
# https://alphafold.ebi.ac.uk/files/AF-C7C422-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-C7C422-F1-model_v2.pdb
# 5u4hA02
# A0A0R0VXX6
# https://alphafold.ebi.ac.uk/files/AF-A0A0R0VXX6-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-A0A0R0VXX6-F1-model_v2.pdb
# codi no executat a Alphafold
# 1ud9A00
# Q975N2
# https://alphafold.ebi.ac.uk/files/AF-Q975N2-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-Q975N2-F1-model_v2.pdb
# 6nibA00
# G7JT50
# https://alphafold.ebi.ac.uk/files/AF-G7JT50-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-G7JT50-F1-model_v2.pdb
# 4fs7A00
# A7M397
# https://alphafold.ebi.ac.uk/files/AF-A7M397-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-A7M397-F1-model_v2.pdb
# codi no executat a Alphafold
# 2w8tA01
# Q93UV0
# https://alphafold.ebi.ac.uk/files/AF-Q93UV0-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-Q93UV0-F1-model_v2.pdb
# codi no executat a Alphafold
# 1vq8L02
# P20276
# https://alphafold.ebi.ac.uk/files/AF-P20276-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-P20276-F1-model_v2.pdb
# 1g6xA00
# P00974
# https://alphafold.ebi.ac.uk/files/AF-P00974-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-P00974-F1-model_v2.pdb
# 3J7O
# 3hrzA06
# Q91132
# https://alphafold.ebi.ac.uk/files/AF-Q91132-F1-predicted_aligned_error_v2.json
# https://alphafold.ebi.ac.uk/files/AF-Q91132-F1-model_v2.pdb
