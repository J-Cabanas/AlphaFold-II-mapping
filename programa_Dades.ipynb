# %% [markdown]
# ## Programa per descargar les dades de CATH
# ---

# %% [markdown]
# Previous libraries that need to be downloaded.
#
# To start working, it will be necessary to create a folder to download the files and change our working directory, going to the folder we have created.

# %%
import os 
import pandas as pd
import wget


datadir=os.path.expanduser('~/data')
RCSB_pdb=os.path.expanduser('~/data/RCSB_pdb')

if os.path.exists(datadir)== False:
    os.mkdir(datadir)
os.chdir(datadir)
# !mkdir RCSB_pdb

# %%
os.getcwd()
# Out:
# '/home/joanc/data'

# %% [markdown]
# To access the information found in CATH, you need the following link and then we can proceed to download.
# * Url: ftp://orengoftp.biochem.ucl.ac.uk/cath/releases/latest-release/cath-classification-data/

# %%
# !wget ftp://orengoftp.biochem.ucl.ac.uk/cath/releases/daily-release/newest/*      ls -ltrsah

# %%
# !wget -nc ftp://orengoftp.biochem.ucl.ac.uk/cath/releases/latest-release/cath-classification-data/cath-domain-description-file.txt


# !wget -nc ftp://orengoftp.biochem.ucl.ac.uk/cath/releases/latest-release/cath-classification-data/cath-names.txt
# Out:
# El fichero “cath-domain-description-file.txt” ya está ahí, no se recupera.
# El fichero “cath-names.txt” ya está ahí, no se recupera.

# %% [markdown]
# The files are compressed, so it will be necessary to decompress them before starting to work with them.

# %%
#!gzip -d *
# this step isn't necessary in the end

# %% [markdown]
# ---
# ### We proceed to work with the files.
#
# We will start by creating a dictionary, which links the code that cath uses with the different hierarchies.

# %%
def read_file(file):            
    f=open(file,"r")            
    list=f.readlines()          
    f.close()                   
    return(list)
def create_dic(list):
    d={}
    d2={}
    for e in list:
        if e[0]!='#':
            v1=e.find("    ")
            cad=e[v1+4:]
            v2=cad.find('    ')
            codeCATH=e[:v1]
            codePDB=cad[:v2]
            node=cad[v2+5:-1]
            d[codeCATH]=codePDB
            d2[codeCATH]=node
    return(d,d2)

# %%
list_Hierarchy= read_file("./cath-names.txt") # We open the file containing the names of the different hierarchies that exist.

# %%
(dic_pdb,dic_node)=create_dic(list_Hierarchy)
dic_pdb
#dic_node
# Out:
# {'1': '1xmkA00',
#  '2': '4unuA00',
#  '3': '1hdoA00',
#  '4': '1g6xA00',
#  '6': '1vwxT02',
#  '1.10': '1xmkA00',
#  '1.20': '2ynzC01',
#  '1.25': '3ro3A00',
#  '1.40': '3iisM00',
#  '1.50': '4ayoA00',
#  '2.10': '3sovA02',
#  '2.20': '6d9nB01',
#  '2.30': '2o9sA00',
#  '2.40': '1x54A01',
#  '2.50': '4mxtA00',
#  '2.60': '4unuA00',
#  '2.70': '1rwhA02',
#  '2.80': '3nbcA00',
#  '2.90': '2dpfA00',
#  '2.100': '3ll2A00',
#  '2.102': '2bmoA02',
#  '2.105': '1n7vA01',
#  '2.110': '3c7xA00',
#  '2.115': '4n1iA00',
#  '2.120': '1pjxA00',
#  '2.130': '2oizA01',
#  '2.140': '4a5sA02',
#  '2.150': '5d7wA01',
#  '2.160': '1k5cA00',
#  '2.170': '3f9xD00',
#  '2.180': '5kisB00',
#  '3.10': '3goeA00',
#  '3.15': '1ewfA01',
#  '3.20': '2vxnA00',
#  '3.30': '6n3dA01',
#  '3.40': '1hdoA00',
#  '3.50': '1lqtB02',
#  '3.55': '4jtmA00',
#  '3.60': '5xp6A00',
#  '3.65': '5u4hA02',
#  '3.70': '1ud9A00',
#  '3.75': '6nibA00',
#  '3.80': '4fs7A00',
#  '3.90': '2w8tA01',
#  '3.100': '1vq8L02',
#  '4.10': '1g6xA00',
#  '6.10': '1vwxT02',
#  '6.20': '3hrzA06',
#  '1.10.8': '1oaiA00',
#  '1.10.10': '1xmkA00',
#  '1.10.12': '5jbxA02',
#  '1.10.15': '4c1nA01',
#  '1.10.20': '4cayB00',
#  '1.10.30': '3fghA00',
#  '1.10.40': '2ptrB03',
#  '1.10.45': '1wvfA04',
#  '1.10.60': '1on2A02',
#  '1.10.100': '1tgrA00',
#  '1.10.101': '4lpqA01',
#  '1.10.110': '4xuwA00',
#  '1.10.132': '3iayA07',
#  '1.10.135': '1m15A01',
#  '1.10.140': '1cmbA00',
#  '1.10.150': '3b0xA02',
#  '1.10.155': '1af7A01',
#  '1.10.166': '3tk8B01',
#  '1.10.167': '6am3A00',
#  '1.10.168': '6faiI03',
#  '1.10.170': '1bvp103',
#  '1.10.185': '1jvrA00',
#  '1.10.189': '1kblA02',
#  '1.10.195': '1vpuA00',
#  '1.10.196': '1dk8A01',
#  '1.10.210': '4cfsA02',
#  '1.10.220': '2ii2A04',
#  '1.10.225': '1l9lA00',
#  '1.10.230': '2ibpA02',
#  '1.10.238': '1psrA00',
#  '1.10.239': '2aibA00',
#  '1.10.240': '1n3lA02',
#  '1.10.245': '5c5aA00',
#  '1.10.246': '5oswA03',
#  '1.10.250': '1bvp101',
#  '1.10.260': '3fymA00',
#  '1.10.268': '4ckkC03',
#  '1.10.269': '2wb0X01',
#  '1.10.274': '1twfA05',
#  '1.10.275': '6n1mA01',
#  '1.10.285': '5gudB01',
#  '1.10.286': '2wscK00',
#  '1.10.287': '3oufB00',
#  '1.10.288': '6bm5A02',
#  '1.10.290': '2gaiA04',
#  '1.10.300': '5i34A02',
#  '1.10.340': '1xqoA02',
#  '1.10.357': '2zcmA00',
#  '1.10.375': '2wlvA00',
#  '1.10.390': '5jviE02',
#  '1.10.400': '1cipA02',
#  '1.10.405': '1d5tA03',
#  '1.10.418': '2vzcB00',
#  '1.10.420': '4bllA02',
#  '1.10.437': '5uukA00',
#  '1.10.439': '1gk9A01',
#  '1.10.440': '2endA00',
#  '1.10.441': '2wfpA03',
#  '1.10.442': '5b1aD00',
#  '1.10.443': '1xo0A02',
#  '1.10.455': '1iqvA00',
#  '1.10.460': '1mw9X02',
#  '1.10.468': '2wjnC02',
#  '1.10.470': '2vsgA02',
#  '1.10.472': '2i53A01',
#  '1.10.486': '3lfuA04',
#  '1.10.489': '6ekzA00',
#  '1.10.490': '5yceA00',
#  '1.10.506': '3fayA00',
#  '1.10.510': '5nkfA02',
#  '1.10.520': '4bllA01',
#  '1.10.530': '2vb1A00',
#  '1.10.532': '1bgfA00',
#  '1.10.533': '1cy5A00',
#  '1.10.540': '2uxwA02',
#  '1.10.555': '2ovjA00',
#  '1.10.560': '1sx3A01',
#  '1.10.565': '1ymtA00',
#  '1.10.569': '4z3xA03',
#  '1.10.575': '5fbfA00',
#  '1.10.579': '5zm0A03',
#  '1.10.580': '2ibpA01',
#  '1.10.590': '5w6yA00',
#  '1.10.599': '1b25A03',
#  '1.10.600': '1wmwB00',
#  '1.10.601': '1sigA00',
#  '1.10.606': '1qi9A00',
#  '1.10.620': '1mxrA00',
#  '1.10.630': '1jfbA00',
#  '1.10.640': '5mfaA00',
#  '1.10.645': '4u9hL00',
#  '1.10.700': '3wrbB02',
#  '1.10.720': '1jeqA05',
#  '1.10.730': '4qreA03',
#  '1.10.740': '1musA03',
#  '1.10.750': '2c9wA02',
#  '1.10.760': '3ziyA03',
#  '1.10.780': '4fasA01',
#  '1.10.790': '3o79B00',
#  '1.10.800': '1j8uA00',
#  '1.10.820': '1heiA03',
#  '1.10.840': '6d55B02',
#  '1.10.860': '6cbrB00',
#  '1.10.870': '1iieA00',
#  '1.10.880': '1sknP00',
#  '1.10.890': '5wkrA02',
#  '1.10.930': '2oq1A02',
#  '1.10.940': '3d3bA00',
#  '1.10.950': '1yu5X00',
#  '1.10.1000': '1xszA02',
#  '1.10.1020': '2g1pA02',
#  '1.10.1030': '1a9xA04',
#  '1.10.1040': '1evyA02',
#  '1.10.1050': '2vqeD01',
#  '1.10.1060': '2h88B02',
#  '1.10.1070': '2wxfA05',
#  '1.10.1080': '3kalA03',
#  '1.10.1090': '2fyuF00',
#  '1.10.1100': '1tbaA00',
#  '1.10.1130': '3bnjA01',
#  '1.10.1140': '2ck3D03',
#  '1.10.1160': '2ja2A03',
#  '1.10.1170': '4hy4B00',
#  '1.10.1180': '1f6vA00',
#  '1.10.1200': '4bpfA00',
#  '1.10.1220': '1irqA00',
#  '1.10.1240': '4jgiA01',
#  '1.10.1270': '4yqaA02',
#  '1.10.1280': '5z0fA00',
#  '1.10.1290': '16vpA00',
#  '1.10.1300': '1tbfA00',
#  '1.10.1320': '1mswD01',
#  '1.10.1330': '5nrmB00',
#  '1.10.1350': '1qhdA02',
#  '1.10.1370': '3ahnB00',
#  '1.10.1380': '6gidA02',
#  '1.10.1390': '2cxnA03',
#  '1.10.1400': '1gk9B03',
#  '1.10.1410': '4ud4A01',
#  '1.10.1420': '1wb9A03',
#  '1.10.1440': '1i5jA00',
#  '1.10.1450': '5m33B00',
#  '1.10.1470': '4z49A02',
#  '1.10.1490': '1iyrA00',
#  '1.10.1500': '2pbyB02',
#  '1.10.1510': '5yrvC02',
#  '1.10.1520': '3o2rA00',
#  '1.10.1530': '1wtjB01',
#  '1.10.1540': '1t77A02',
#  '1.10.1580': '3cnlA02',
#  '1.10.1600': '1jeyA04',
#  '1.10.1610': '4kqkB01',
#  '1.10.1620': '2v7qI00',
#  '1.10.1630': '1zoqC00',
#  '1.10.1650': '1vq8P01',
#  '1.10.1660': '1q08A00',
#  '1.10.1670': '2xhiA02',
#  '1.10.1710': '3mw6C00',
#  '1.10.1720': '1e5rB02',
#  '1.10.1740': '4lupA00',
#  '1.10.1750': '3pvvA00',
#  '1.10.1760': '3rlbA00',
#  '1.10.1780': '3wdcA00',
#  '1.10.1790': '3nufB00',
#  '1.10.1810': '1tkvA00',
#  '1.10.1820': '1qf8A01',
#  '1.10.1840': '5c5oA03',
#  '1.10.1850': '1tx9A00',
#  '1.10.1870': '2axqA03',
#  '1.10.1900': '3kujA01',
#  '1.10.2000': '1ijyA00',
#  '1.10.2010': '1j0tA00',
#  '1.10.2020': '2qeeA02',
#  '1.10.2030': '4pkwA02',
#  '1.10.2040': '1jmuB02',
#  '1.10.2050': '1jmuB03',
#  '1.10.2060': '1k87A02',
#  '1.10.2080': '1n8vB00',
#  '1.10.2090': '5tuxA01',
#  '1.10.3020': '3i2kA02',
#  '1.10.3030': '1n81A00',
#  '1.10.3040': '1n93X01',
#  '1.10.3050': '1n93X02',
#  '1.10.3060': '2fsiB04',
#  '1.10.3070': '1nxhA00',
#  '1.10.3080': '4eneB00',
#  '1.10.3090': '4wbyA02',
#  '1.10.3100': '2ox6D00',
#  '1.10.3110': '3lovA03',
#  '1.10.3120': '2nsaA00',
#  '1.10.3130': '3q1xA01',
#  '1.10.3140': '1u8vA01',
#  '1.10.3160': '4b2fA00',
#  '1.10.3170': '1w36B02',
#  '1.10.3180': '4zdsB00',
#  '1.10.3190': '1wpbB02',
#  '1.10.3200': '4y97D00',
#  '1.10.3210': '3m1tA00',
#  '1.10.3230': '1vt0k00',
#  '1.10.3250': '1wteB01',
#  '1.10.3260': '2cfmA01',
#  '1.10.3270': '2r4fD01',
#  '1.10.3280': '1kyqA03',
#  '1.10.3290': '5cklA00',
#  '1.10.3300': '3h0nA00',
#  '1.10.3320': '2gviA01',
#  '1.10.3330': '3o7iA00',
#  '1.10.3340': '3fybB00',
#  '1.10.3350': '4u12A00',
#  '1.10.3360': '2p3yA02',
#  '1.10.3370': '5awwY00',
#  '1.10.3380': '2zj8A03',
#  '1.10.3390': '2oa5A01',
#  '1.10.3400': '2ph7A01',
#  '1.10.3410': '3bg2A03',
#  '1.10.3420': '2yf4F00',
#  '1.10.3430': '3b9wA00',
#  '1.10.3440': '2pv4A00',
#  '1.10.3450': '2ijqB00',
#  '1.10.3460': '2bhwA01',
#  '1.10.3470': '2nq2A00',
#  '1.10.3480': '1s9uA00',
#  '1.10.3490': '2p62A02',
#  '1.10.3500': '3bzcA02',
#  '1.10.3510': '2o5hA00',
#  '1.10.3520': '3rznA01',
#  '1.10.3530': '2ijrA02',
#  '1.10.3540': '3bhwA00',
#  '1.10.3550': '3bg2A02',
#  '1.10.3560': '2jynA01',
#  '1.10.3570': '3hhwK01',
#  '1.10.3580': '2r31A02',
#  '1.10.3590': '2qtsA03',
#  '1.10.3600': '3c4rA00',
#  '1.10.3610': '3hhwK02',
#  '1.10.3620': '3ca8A01',
#  '1.10.3630': '2zihC00',
#  '1.10.3640': '3c24A02',
#  '1.10.3650': '1q16B03',
#  '1.10.3660': '2f1kC02',
#  '1.10.3670': '4q68A01',
#  '1.10.3680': '2h5nC00',
#  '1.10.3690': '2igsA00',
#  '1.10.3700': '2o8sA01',
#  '1.10.3710': '2r9gA02',
#  '1.10.3720': '3rlfF04',
#  '1.10.3730': '5bseA02',
#  '1.10.3740': '2i71A02',
#  '1.10.3750': '1sedA00',
#  '1.10.3760': '1y9iA00',
#  '1.10.3780': '3ckcA03',
#  '1.10.3790': '1pc6A00',
#  '1.10.3800': '2auaA02',
#  '1.10.3810': '2oqoA00',
#  '1.10.3820': '2j7aC00',
#  '1.10.3830': '2kdcA00',
#  '1.10.3860': '6r7rB00',
#  '1.10.3870': '1y8aA02',
#  '1.10.3880': '1t07A00',
#  '1.10.3890': '1sdiA00',
#  '1.10.3900': '2oezB02',
#  '1.10.3910': '2fi0A00',
#  '1.10.3920': '2fefA02',
#  '1.10.3930': '1s9rA02',
#  '1.10.3940': '3dt5A00',
#  '1.10.3950': '3fh3A00',
#  '1.10.3960': '1tm9A00',
#  '1.10.3970': '1x3aA00',
#  '1.10.3980': '1vrmA02',
#  '1.10.3990': '3kk4A01',
#  '1.10.4000': '1g8eB00',
#  '1.10.4010': '1w2yA00',
#  '1.10.4020': '3lhrB00',
#  '1.10.4030': '3rgcA01',
#  '1.10.4040': '1sd4A02',
#  '1.10.4050': '1v4aA01',
#  '1.10.4060': '1zboA02',
#  '1.10.4070': '2o9xA02',
#  '1.10.4080': '6g1pB00',
#  '1.10.4090': '5gmzA00',
#  '1.10.4100': '2hp0A01',
#  '1.10.4110': '1q5zA00',
#  '1.10.4120': '1gzsB00',
#  '1.10.4140': '3nb2A04',
#  '1.10.4150': '2fm9A00',
#  '1.10.4160': '2jlnA00',
#  '1.10.4170': '2jo7A00',
#  '1.10.4180': '2vy1A00',
#  '1.10.4190': '3cxnB00',
#  '1.10.4200': '3h9pB00',
#  '1.20.5': '2ynzC01',
#  '1.20.10': '1ehsA00',
#  '1.20.20': '2xquA01',
#  '1.20.50': '2jmsA01',
#  '1.20.58': '3edvA01',
#  '1.20.59': '2d8dB00',
#  '1.20.80': '6ibeA02',
#  '1.20.81': '2fcwA00',
#  '1.20.82': '4cmhA01',
#  '1.20.85': '1rzhM01',
#  '1.20.89': '3aekB03',
#  '1.20.90': '1mc2A00',
#  '1.20.91': '4p3aA00',
#  '1.20.120': '4ebjA02',
#  '1.20.140': '5zw7A03',
#  '1.20.141': '4oltB01',
#  '1.20.142': '4zzxA01',
#  '1.20.144': '3bb0A01',
#  '1.20.150': '5ii8A00',
#  '1.20.190': '3x0uB01',
#  '1.20.200': '1gkmA02',
#  '1.20.210': '5b1aA00',
#  '1.20.225': '4rgdA00',
#  '1.20.245': '4wfoA05',
#  '1.20.250': '1ciiA01',
#  '1.20.272': '3bgeA01',
#  '1.20.810': '3cx5C00',
#  '1.20.840': '5a0yA03',
#  '1.20.850': '4fasA02',
#  '1.20.860': '1jb0K00',
#  '1.20.870': '6d55B01',
#  '1.20.890': '3g36B00',
#  '1.20.900': '4yonA01',
#  '1.20.910': '3b5oA00',
#  '1.20.920': '5ig6A00',
#  '1.20.930': '3nfqB02',
#  '1.20.940': '1dvkA00',
#  '1.20.950': '1kqfC00',
#  '1.20.960': '4zpcA03',
#  '1.20.970': '2elcA01',
#  '1.20.990': '3qfsA02',
#  '1.20.1000': '1f5nA01',
#  '1.20.1020': '3t92A00',
#  '1.20.1050': '4mf5A02',
#  '1.20.1060': '6fbcA02',
#  '1.20.1070': '5zimA00',
#  '1.20.1080': '3zojA00',
#  '1.20.1090': '5br4A02',
#  '1.20.1110': '3ar4A02',
#  '1.20.1120': '1epwA02',
#  '1.20.1130': '1jb0B00',
#  '1.20.1150': '2c0gA02',
#  '1.20.1160': '4fqnC00',
#  '1.20.1170': '4phqA00',
#  '1.20.1180': '4e6uA02',
#  '1.20.1200': '3ci3A01',
#  '1.20.1220': '5vfbA03',
#  '1.20.1230': '1jadA00',
#  '1.20.1240': '5oy0000',
#  '1.20.1250': '2d48A00',
#  '1.20.1260': '6b8fA00',
#  '1.20.1270': '2d1lA00',
#  '1.20.1280': '2e31A01',
#  '1.20.1290': '2oyoA02',
#  '1.20.1300': '2h88C02',
#  '1.20.1310': '2wzkA01',
#  '1.20.1320': '5jajA03',
#  '1.20.1330': '2d4xA00',
#  '1.20.1340': '3k40A01',
#  '1.20.1370': '3wkyB01',
#  '1.20.1380': '3sk7A00',
#  '1.20.1390': '3v53E00',
#  '1.20.1400': '1t50A00',
#  '1.20.1410': '1r0dB00',
#  '1.20.1420': '4w8pA01',
#  '1.20.1430': '3p0bA02',
#  '1.20.1440': '2qsbA00',
#  '1.20.1450': '4phzB00',
#  '1.20.1460': '3rrkA02',
#  '1.20.1480': '3vjfA00',
#  '1.20.1500': '2iazA00',
#  '1.20.1510': '3h90A01',
#  '1.20.1520': '4zi3D00',
#  '1.20.1530': '4n7wA00',
#  '1.20.1540': '2xovA00',
#  '1.20.1550': '2zuqA00',
#  '1.20.1560': '4a82A01',
#  '1.20.1570': '3bh1A02',
#  '1.20.1580': '2vf7A02',
#  '1.20.1590': '2q9rA01',
#  '1.20.1600': '5azpB01',
#  '1.20.1610': '2ww2A04',
#  '1.20.1630': '2vpzC00',
#  '1.20.1640': '4dx5C01',
#  '1.20.1650': '2qmaA01',
#  '1.20.1660': '2b6cA01',
#  '1.20.1670': '4dk2A02',
#  '1.20.1680': '4dk2A01',
#  '1.20.1690': '3s6pD01',
#  '1.20.1700': '1q16A10',
#  '1.20.1710': '3nftA00',
#  '1.20.1720': '2gfpA00',
#  '1.20.1730': '3dh4A01',
#  '1.20.1740': '3giaA00',
#  '1.25.10': '4uafB00',
#  '1.25.20': '1qsaA01',
#  '1.25.40': '3ro3A00',
#  '1.25.50': '6q4rA04',
#  '1.25.60': '2ouxA01',
#  '1.25.70': '3m66A00',
#  '1.40.10': '3iisM00',
#  '1.40.20': '6qv7A00',
#  '1.50.10': '4ayoA00',
#  '1.50.40': '1okcA00',
#  '2.10.10': '1h8pA02',
#  '2.10.22': '1bx7A00',
#  '2.10.25': '3sovA02',
#  '2.10.50': '3wvtA01',
#  '2.10.55': '1lmlA03',
#  '2.10.60': '2j8bA00',
#  '2.10.69': '2fj8A01',
#  '2.10.70': '4k12A00',
#  '2.10.77': '3ku3A01',
#  '2.10.80': '1lpbA00',
#  '2.10.90': '1mkkB00',
#  '2.10.109': '3k2zA02',
#  '2.10.110': '4hi8B00',
#  '2.10.150': '4gy7A03',
#  '2.10.160': '4deqA02',
#  '2.10.210': '1ppjI00',
#  '2.10.220': '4c9rD00',
#  '2.10.230': '1nltA02',
#  '2.10.240': '1ep3B03',
#  '2.10.250': '1jhnA02',
#  '2.10.260': '5itmA00',
#  '2.10.270': '2f6eA00',
#  '2.10.280': '1h6wA01',
#  '2.10.290': '2jneA00',
#  '2.10.300': '1uunA02',
#  '2.10.310': '1qmbB00',
#  '2.20.20': '4gv5A00',
#  '2.20.25': '6d9nB01',
#  '2.20.28': '2dsxA00',
#  '2.20.50': '1lshA03',
#  '2.20.60': '1mknA00',
#  '2.20.70': '1pinA01',
#  '2.20.80': '1lshA04',
#  '2.20.90': '1lshB00',
#  '2.20.100': '6b0sC00',
#  '2.20.110': '3m58A01',
#  '2.20.120': '2j8gA03',
#  '2.20.130': '3hrzB01',
#  '2.20.140': '2ra8A01',
#  '2.20.150': '3pl2A02',
#  '2.20.160': '1ya5T01',
#  '2.20.170': '3bxjA01',
#  '2.20.180': '2r01A02',
#  '2.20.200': '5azpA02',
#  '2.20.210': '6c6zA02',
#  '2.20.220': '3pqhA01',
#  '2.20.230': '3eo5A01',
#  '2.30.18': '1nh2D02',
#  '2.30.22': '1dkgB02',
#  '2.30.24': '3rioA01',
#  '2.30.26': '2e6fA02',
#  '2.30.27': '1g3pA01',
#  '2.30.29': '1unqA00',
#  '2.30.30': '2o9sA00',
#  '2.30.31': '2it9A00',
#  '2.30.32': '1e8rA00',
#  '2.30.33': '1g31A00',
#  '2.30.34': '1lmlA04',
#  '2.30.36': '2pbdA02',
#  '2.30.38': '2d1sA01',
#  '2.30.39': '5c98B02',
#  '2.30.40': '1ra0A01',
#  '2.30.42': '4z8jA00',
#  '2.30.60': '2rdkA00',
#  '2.30.90': '1mkcA00',
#  '2.30.110': '2r0xA00',
#  '2.30.120': '1gk9B02',
#  '2.30.130': '3d79A02',
#  '2.30.140': '2i7cA01',
#  '2.30.150': '2a6hC04',
#  '2.30.160': '1fjrA01',
#  '2.30.170': '5dm6U00',
#  '2.30.180': '1o70A01',
#  '2.30.210': '2v0cA03',
#  '2.30.220': '1io1A03',
#  '2.30.230': '1lshA01',
#  '2.30.240': '1yduA01',
#  '2.30.250': '5jgfA02',
#  '2.30.260': '4q68A02',
#  '2.30.270': '2ra9A02',
#  '2.30.280': '3fdeB01',
#  '2.30.290': '5dmdA00',
#  '2.30.300': '1wruA01',
#  '2.30.310': '5h3xA01',
#  '2.30.320': '1pv5A00',
#  '2.30.330': '4yx1A00',
#  '2.30.340': '1yvuA02',
#  '2.40.10': '5avdA02',
#  '2.40.15': '1a1xA00',
#  '2.40.20': '6dcmA00',
#  '2.40.30': '3w5hA01',
#  '2.40.33': '2g50F03',
#  '2.40.37': '1rcqA01',
#  '2.40.40': '1pqhB00',
#  '2.40.50': '1x54A01',
#  '2.40.70': '1bxoA02',
#  '2.40.100': '4o8hA00',
#  '2.40.110': '5zw7A02',
#  '2.40.128': '3kffA00',
#  '2.40.150': '1whiA00',
#  '2.40.155': '6jgjA00',
#  '2.40.160': '5fvnA00',
#  '2.40.170': '5fokB02',
#  '2.40.180': '3ttvA01',
#  '2.40.200': '1jb7B00',
#  '2.40.220': '4xjwA03',
#  '2.40.230': '1qd5A00',
#  '2.40.240': '3aiiA03',
#  '2.40.250': '3wttB00',
#  '2.40.260': '2w1jA00',
#  '2.40.270': '1twfB06',
#  '2.40.280': '1wjxA00',
#  '2.40.290': '1ow1A00',
#  '2.40.300': '1c5eA00',
#  '2.40.310': '1nycA00',
#  '2.40.320': '5a67A00',
#  '2.40.330': '4i1kA00',
#  '2.40.340': '6fgdA04',
#  '2.40.350': '2q03B00',
#  '2.40.360': '2in5A00',
#  '2.40.370': '2ichA01',
#  '2.40.380': '3exmA01',
#  '2.40.390': '2o3iA02',
#  '2.40.400': '4zboC00',
#  '2.40.410': '3c8iA00',
#  '2.40.420': '4l8jA01',
#  '2.40.430': '3rlfF03',
#  '2.40.440': '6d4kA02',
#  '2.40.450': '2gmqA00',
#  '2.40.460': '4wz8B02',
#  '2.40.470': '1ye9A02',
#  '2.40.480': '4h6cB00',
#  '2.40.490': '4gipD02',
#  '2.40.500': '1h5wB02',
#  '2.40.510': '4ooxA01',
#  '2.50.10': '3eojA00',
#  '2.50.20': '4mxtA00',
#  '2.60.9': '2hnuA00',
#  '2.60.11': '5b1aF00',
#  '2.60.15': '2e5yA01',
#  '2.60.20': '4iauA02',
#  '2.60.30': '2oizH00',
#  '2.60.34': '4f01B01',
#  '2.60.40': '4unuA00',
#  '2.60.60': '4wfoA01',
#  '2.60.90': '6fjnA00',
#  '2.60.98': '1svbA01',
#  '2.60.110': '5x9lA00',
#  '2.60.120': '5k8sB00',
#  '2.60.130': '4whsD00',
#  '2.60.169': '2bpa100',
#  '2.60.175': '4mbyH00',
#  '2.60.200': '2pieA01',
#  '2.60.210': '4ysiA00',
#  '2.60.220': '1rwhA03',
#  '2.60.240': '1cq3A00',
#  '2.60.250': '1p35C00',
#  '2.60.260': '3tj8A01',
#  '2.60.270': '4wdcA00',
#  '2.60.290': '1nc7A00',
#  '2.60.300': '1r94A00',
#  '2.60.310': '1js8B02',
#  '2.60.320': '3ld7A00',
#  '2.60.330': '1n7vA02',
#  '2.60.340': '1n7zA01',
#  '2.60.350': '1x0cA01',
#  '2.60.370': '1so9A00',
#  '2.60.390': '3og2A03',
#  '2.60.410': '3mzfA02',
#  '2.60.420': '1v7wA02',
#  '2.60.430': '2p84A01',
#  '2.60.440': '2oezA01',
#  '2.60.450': '2r19A00',
#  '2.60.460': '2qzbA00',
#  '2.60.470': '2qtsA02',
#  '2.60.480': '3g74C00',
#  '2.60.490': '5svkA02',
#  '2.60.500': '1ywmA01',
#  '2.60.510': '1gkuB07',
#  '2.60.520': '1zruC01',
#  '2.60.530': '3ioxA02',
#  '2.70.9': '2obeA04',
#  '2.70.10': '2pw8I00',
#  '2.70.20': '1mw9X03',
#  '2.70.40': '1euwA00',
#  '2.70.50': '4eirA00',
#  '2.70.70': '4qp5A00',
#  '2.70.98': '1rwhA02',
#  '2.70.100': '2v3iA00',
#  '2.70.130': '1gp0A00',
#  '2.70.150': '3ar4A01',
#  '2.70.160': '4c08A02',
#  '2.70.170': '2wn9D00',
#  '2.70.180': '1njhA00',
#  '2.70.210': '5m04A01',
#  '2.70.220': '2ag4A00',
#  '2.70.230': '3w9eC00',
#  '2.70.240': '4iyaA00',
#  '2.70.250': '1n7vA03',
#  '2.80.10': '3nbcA00',
#  '2.80.20': '1yu0A02',
#  '2.90.10': '2dpfA00',
#  '2.90.20': '6b0gE00',
#  '2.100.10': '3ll2A00',
#  '2.102.10': '2bmoA02',
#  '2.102.20': '3og2A02',
#  '2.102.30': '3dclA01',
#  '2.105.10': '1n7vA01',
#  '2.110.10': '3c7xA00',
#  '2.115.10': '4n1iA00',
#  '2.120.10': '1pjxA00',
#  '2.130.10': '2oizA01',
#  '2.140.10': '4a5sA02',
#  '2.150.10': '5d7wA01',
#  '2.160.10': '3kwdA00',
#  '2.160.20': '1k5cA00',
#  '2.160.30': '1h6wA02',
#  '2.170.8': '4gmuA02',
#  '2.170.9': '2obeB02',
#  '2.170.11': '1oisA02',
#  '2.170.14': '2xc1A01',
#  '2.170.15': '2d42A01',
#  '2.170.16': '6freA00',
#  '2.170.30': '3ng9A00',
#  '2.170.40': '4jzzA01',
#  '2.170.120': '2pa8D02',
#  '2.170.130': '1kmoA01',
#  '2.170.140': '1dqcA00',
#  '2.170.150': '5amhA00',
#  '2.170.160': '5yj6A02',
#  '2.170.170': '3s9zA02',
#  '2.170.180': '1fjrA02',
#  '2.170.190': '6fgcA03',
#  '2.170.200': '2nnuA02',
#  '2.170.210': '2y3vD00',
#  '2.170.220': '2d5bA02',
#  '2.170.230': '1b12A02',
#  '2.170.240': '1t60D00',
#  '2.170.260': '4z4dA02',
#  '2.170.270': '3f9xD00',
#  '2.170.280': '1io1A02',
#  '2.170.290': '1n7zA02',
#  '2.170.300': '2gy5A03',
#  '2.180.10': '5kisB00',
#  '3.10.10': '4g1qB01',
#  '3.10.20': '3goeA00',
#  '3.10.25': '2blnA02',
#  '3.10.28': '2ab5A01',
#  '3.10.40': '3g4nA01',
#  '3.10.50': '2y78A00',
#  '3.10.100': '3wh3A00',
#  '3.10.105': '1jetA03',
#  '3.10.110': '1z2uA00',
#  '3.10.120': '3x34A00',
#  '3.10.129': '4mtuA00',
#  '3.10.130': '1dy5A00',
#  '3.10.150': '4k3lB02',
#  '3.10.170': '5jviE01',
#  '3.10.180': '1nkiA00',
#  '3.10.196': '6bdyA01',
#  '3.10.200': '3ks3A00',
#  '3.10.250': '1z8gA01',
#  '3.10.260': '1l8rB00',
#  '3.10.270': '3l8wA00',
#  '3.10.280': '3jv1A00',
#  '3.10.290': '1dm9A00',
#  '3.10.300': '3ubyA00',
#  '3.10.310': '4jbdA02',
#  '3.10.320': '4x5wA01',
#  '3.10.330': '5b6cA02',
#  '3.10.340': '4gvqA01',
#  '3.10.350': '5k2lA00',
#  '3.10.360': '1fd3A00',
#  '3.10.380': '2b5uA03',
#  '3.10.390': '1oqjA00',
#  '3.10.400': '1r6xA01',
#  '3.10.410': '3do6A03',
#  '3.10.420': '2hngA00',
#  '3.10.430': '1divA02',
#  '3.10.440': '1vq8X00',
#  '3.10.450': '6c1xA00',
#  '3.10.460': '2w2sA00',
#  '3.10.470': '1t23A00',
#  '3.10.490': '3judA00',
#  '3.10.500': '1x9yA01',
#  '3.10.510': '2h7aA01',
#  '3.10.520': '4xduA00',
#  '3.10.530': '2jovA01',
#  '3.10.540': '2ra9A01',
#  '3.10.550': '2hlyA00',
#  '3.10.560': '2j58A01',
#  '3.10.570': '3ib5A00',
#  '3.10.580': '2uv4A00',
#  '3.10.590': '2hd9A00',
#  '3.10.600': '2qf7A03',
#  '3.10.610': '3ci0J01',
#  '3.10.620': '2zk9X00',
#  '3.10.630': '3bh1A01',
#  '3.10.640': '2g3wA00',
#  '3.10.650': '3rlfF02',
#  '3.10.660': '4x33A00',
#  '3.10.670': '4g29A00',
#  '3.10.680': '5b66B02',
#  '3.10.690': '1vjlA00',
#  '3.15.10': '1ewfA01',
#  '3.15.20': '1ewfA02',
#  '3.15.30': '3bqwA01',
#  '3.20.10': '2eiyB02',
#  '3.20.14': '3a9sA03',
#  '3.20.16': '4p3hA00',
#  '3.20.19': '3h5jA00',
#  '3.20.20': '2vxnA00',
#  '3.20.70': '3o0qA00',
#  '3.20.80': '3r8jA00',
#  '3.20.90': '3c5nA00',
#  '3.20.100': '3bgyA00',
#  '3.20.110': '3bvxA01',
#  '3.20.120': '2b97A00',
#  '3.20.130': '2isbA00',
#  '3.20.140': '3os4A00',
#  '3.20.160': '2qhqB00',
#  '3.20.170': '2o0qA00',
#  '3.20.180': '2arzA02',
#  '3.20.190': '1k3xA01',
#  '3.20.200': '3lkmA02',
#  '3.30.9': '3nycA02',
#  '3.30.10': '5e10A02',
#  '3.30.20': '3wh1A02',
#  '3.30.30': '3psmA00',
#  '3.30.40': '3t7lA00',
#  '3.30.43': '1zr6A01',
#  '3.30.44': '1kvdB00',
#  '3.30.46': '3thrA01',
#  '3.30.50': '3fylA00',
#  '3.30.54': '1v4pA02',
#  '3.30.56': '2cxiA01',
#  '3.30.60': '1r0rI00',
#  '3.30.62': '4u5wA00',
#  '3.30.63': '1kgdA02',
#  '3.30.65': '1yuaA01',
#  '3.30.66': '2f4qA01',
#  '3.30.67': '5jhmA02',
#  '3.30.70': '6n3dA01',
#  '3.30.110': '3hz7A00',
#  '3.30.160': '4gznC02',
#  '3.30.170': '1cksB00',
#  '3.30.190': '4reoA01',
#  '3.30.200': '6hmqA02',
#  '3.30.210': '3b0xA04',
#  '3.30.230': '1nz0D00',
#  '3.30.240': '4xr8F01',
#  '3.30.250': '5jrjA02',
#  '3.30.260': '1kp8A02',
#  '3.30.280': '5ol4A00',
#  '3.30.300': '6d9nA02',
#  '3.30.305': '2hdiB00',
#  '3.30.310': '3na5A04',
#  '3.30.342': '3qexA01',
#  '3.30.350': '2sicI00',
#  '3.30.360': '6gg7A02',
#  '3.30.365': '4usaA04',
#  '3.30.370': '5f4cA00',
#  '3.30.379': '1gqiA01',
#  '3.30.380': '2qudA00',
#  '3.30.386': '4oltA02',
#  '3.30.387': '4gsxA03',
#  '3.30.390': '1r0mA01',
#  '3.30.410': '1ju2A02',
#  '3.30.412': '3g4nA02',
#  '3.30.413': '6c3mA02',
#  '3.30.420': '3i33A01',
#  '3.30.428': '3oheA00',
#  '3.30.429': '3b64A00',
#  '3.30.430': '3a2eA00',
#  '3.30.450': '1nwzA00',
#  '3.30.457': '3vz9B00',
#  '3.30.460': '3hj4A02',
#  '3.30.465': '2vfrA02',
#  '3.30.470': '1kjqB03',
#  '3.30.479': '3d7jA00',
#  '3.30.497': '6hgmA01',
#  '3.30.499': '1c96A01',
#  '3.30.500': '1k5nA01',
#  '3.30.505': '5gjiA00',
#  '3.30.519': '1d5tA02',
#  '3.30.530': '4bk7A00',
#  '3.30.540': '5iz3A01',
#  '3.30.559': '2rkvA02',
#  '3.30.560': '3qvpA03',
#  '3.30.565': '5cphA00',
#  '3.30.572': '6nnrA00',
#  '3.30.590': '1m15A02',
#  '3.30.700': '1x6zA00',
#  '3.30.710': '4bgcA00',
#  '3.30.720': '1u7iA02',
#  '3.30.730': '2kvtA00',
#  '3.30.740': '2xqqC00',
#  '3.30.750': '1h4xA00',
#  '3.30.760': '4ue8A00',
#  '3.30.780': '5zcyA00',
#  '3.30.800': '3x01B01',
#  '3.30.810': '3x01B02',
#  '3.30.830': '3go9A02',
#  '3.30.860': '3a1pB00',
#  '3.30.870': '1v0uA01',
#  '3.30.890': '6c1tA00',
#  '3.30.900': '5c50B00',
#  '3.30.910': '1u2mB00',
#  '3.30.920': '1whzA00',
#  '3.30.930': '4xemA01',
#  '3.30.950': '2z6rA02',
#  '3.30.960': '3agkA01',
#  '3.30.980': '1v4pC01',
#  '3.30.990': '1qd1A01',
#  '3.30.1010': '4uwhA02',
#  '3.30.1020': '3a2vD02',
#  '3.30.1030': '4gvqA02',
#  '3.30.1040': '4hscX02',
#  '3.30.1050': '1pz4A00',
#  '3.30.1060': '4gwbA00',
#  '3.30.1070': '3ku7B00',
#  '3.30.1110': '2absA02',
#  '3.30.1120': '1hdhA02',
#  '3.30.1130': '2o90A00',
#  '3.30.1140': '2vqeC02',
#  '3.30.1150': '4g7xB00',
#  '3.30.1160': '1dw9A02',
#  '3.30.1170': '1gaxA04',
#  '3.30.1180': '4x9xA02',
#  '3.30.1190': '1nr3A00',
#  '3.30.1200': '1n91A00',
#  '3.30.1220': '1nijA02',
#  '3.30.1230': '6az1Y00',
#  '3.30.1240': '2rbkA02',
#  '3.30.1250': '2wbmA01',
#  '3.30.1280': '2zw2A00',
#  '3.30.1300': '5bw0F00',
#  '3.30.1310': '1j8bA00',
#  '3.30.1320': '3bn0A00',
#  '3.30.1330': '1xbiA00',
#  '3.30.1340': '3ccdA00',
#  '3.30.1350': '1ejgA00',
#  '3.30.1360': '1xppD00',
#  '3.30.1370': '1zzkA00',
#  '3.30.1380': '3k7iB00',
#  '3.30.1390': '3dnjA00',
#  '3.30.1400': '1f46B00',
#  '3.30.1410': '1jg5A00',
#  '3.30.1420': '1sauA01',
#  '3.30.1430': '1vq8B03',
#  '3.30.1440': '1iq4A00',
#  '3.30.1450': '3d4eA01',
#  '3.30.1460': '4g6tA00',
#  '3.30.1470': '1jb0D00',
#  '3.30.1480': '1k0rA01',
#  '3.30.1490': '1kjqB02',
#  '3.30.1500': '4o6uA00',
#  '3.30.1510': '3do6A02',
#  '3.30.1520': '1kq6A00',
#  '3.30.1530': '1o9iA02',
#  '3.30.1540': '2yimA02',
#  '3.30.1550': '3cjsB00',
#  '3.30.1560': '1oo0A00',
#  '3.30.1570': '1hufA00',
#  '3.30.1580': '2l6qA00',
#  '3.30.1590': '3hjeA02',
#  '3.30.1600': '4bn4A02',
#  '3.30.1610': '5hb6B00',
#  '3.30.1620': '1l1lA02',
#  '3.30.1640': '4ywkA01',
#  '3.30.1650': '1oaoC03',
#  '3.30.1660': '2ux9C00',
#  '3.30.1670': '1okgA03',
#  '3.30.1680': '4wk0B01',
#  '3.30.1690': '3vorA00',
#  '3.30.1700': '3p3eA02',
#  '3.30.1710': '1qysA00',
#  '3.30.1730': '1t8sA01',
#  '3.30.1740': '3od8F00',
#  '3.30.1750': '1vclA03',
#  '3.30.1760': '1vk1A02',
#  '3.30.1770': '2py5A03',
#  '3.30.1780': '1x7dB01',
#  '3.30.1790': '1td6A02',
#  '3.30.1810': '2hh8A00',
#  '3.30.1820': '2iayA00',
#  '3.30.1830': '2joeA01',
#  '3.30.1840': '1xdpA02',
#  '3.30.1850': '3bq9A01',
#  '3.30.1860': '2qyaA01',
#  '3.30.1870': '2qgmA02',
#  '3.30.1880': '5z0fB01',
#  '3.30.1890': '4e29B00',
#  '3.30.1900': '3f2bA04',
#  '3.30.1910': '4zyaB00',
#  '3.30.1920': '3cddB03',
#  '3.30.1930': '3bqwA02',
#  '3.30.1940': '3bu2A02',
#  '3.30.1950': '2j58A03',
#  '3.30.1960': '2it2B00',
#  '3.30.1970': '2fdoA00',
#  '3.30.1980': '1qw2A00',
#  '3.30.1990': '1sr8A01',
#  '3.30.2000': '4acvB00',
#  '3.30.2010': '4jiuA00',
#  '3.30.2020': '3k8rA01',
#  '3.30.2030': '2v7sA00',
#  '3.30.2040': '2pifA02',
#  '3.30.2050': '5b66O02',
#  '3.30.2060': '3fpnB00',
#  '3.30.2070': '2vpzA04',
#  '3.30.2080': '2ww2A02',
#  '3.30.2090': '4dx5A04',
#  '3.30.2110': '1sr8A02',
#  '3.30.2120': '1r7lA00',
#  '3.30.2130': '1zhvA00',
#  '3.30.2140': '1w5rA01',
#  '3.30.2150': '1nt2B01',
#  '3.30.2160': '3h1dA02',
#  '3.30.2170': '3gocA00',
#  '3.30.2180': '2r31A01',
#  '3.30.2190': '2gukA00',
#  '3.30.2200': '3fn2A00',
#  '3.30.2210': '3fy6D01',
#  '3.30.2220': '3fgxA00',
#  '3.30.2230': '4a3pA01',
#  '3.30.2240': '3bl9B02',
#  '3.30.2250': '1ro2A02',
#  '3.30.2260': '2nmlA00',
#  '3.30.2270': '2gagD00',
#  '3.30.2280': '1sgoA01',
#  '3.30.2290': '5nj9D01',
#  '3.30.2300': '1vbkA02',
#  '3.30.2310': '4lttA00',
#  '3.30.2320': '2pk8A00',
#  '3.30.2330': '3it4B01',
#  '3.30.2340': '1szwA02',
#  '3.30.2350': '4lgtA02',
#  '3.30.2360': '1p1hB01',
#  '3.30.2370': '3ic3A01',
#  '3.30.2380': '4ww7B00',
#  '3.30.2390': '4kk7A01',
#  '3.30.2400': '3dktA01',
#  '3.30.2410': '3h1dA03',
#  '3.30.2420': '1u07B00',
#  '3.30.2430': '3bo6B01',
#  '3.30.2440': '3cxbA01',
#  '3.30.2450': '2lezA00',
#  ...}

# %% [markdown]
# ---

# %% [markdown]
# ### We proceed to extract the data from the pdb and AlphaFold web

# %% [markdown]
# We will need the following links, where they will be completed with the program:
#
# * url: https://files.rcsb.org/view/CodePDB.pdb
# * url: https://alphafold.ebi.ac.uk/files/AF-CodeUniProt-F1-predicted_aligned_error_v2.json
# * url: https://alphafold.ebi.ac.uk/files/AF-CodeUniProt-F1-model_v2.pdb

# %% [markdown]
# We will use the dictionary created earlier.

# %%
os.chdir(RCSB_pdb)

# %%
def download_file(dic):
    for k in dic:
        if k.count(".")==3:
            code_PDB=(dic[k])[:-3]+".pdb"
            url='https://files.rcsb.org/view/' + code_PDB
            if os.path.exists(code_PDB)==False:
                file_name=wget.download(url)
download_file(dic_pdb)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_24848/3387163844.py in <module>
#       6             if os.path.exists(code_PDB)==False:
#       7                 file_name=wget.download(url)
# ----> 8 download_file(dic_pdb)
#
# /tmp/ipykernel_24848/3387163844.py in download_file(dic)
#       5             url='https://files.rcsb.org/view/' + code_PDB
#       6             if os.path.exists(code_PDB)==False:
# ----> 7                 file_name=wget.download(url)
#       8 download_file(dic_pdb)
#
# ~/anaconda3/lib/python3.9/site-packages/wget.py in download(url, out, bar)
#     524     else:
#     525         binurl = url
# --> 526     (tmpfile, headers) = ulib.urlretrieve(binurl, tmpfile, callback)
#     527     filename = detect_filename(url, out, headers)
#     528     if outdir:
#
# ~/anaconda3/lib/python3.9/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     266
#     267             while True:
# --> 268                 block = fp.read(bs)
#     269                 if not block:
#     270                     break
#
# ~/anaconda3/lib/python3.9/http/client.py in read(self, amt)
#     460             # Amount is given, implement using readinto
#     461             b = bytearray(amt)
# --> 462             n = self.readinto(b)
#     463             return memoryview(b)[:n].tobytes()
#     464         else:
#
# ~/anaconda3/lib/python3.9/http/client.py in readinto(self, b)
#     494
#     495         if self.chunked:
# --> 496             return self._readinto_chunked(b)
#     497
#     498         if self.length is not None:
#
# ~/anaconda3/lib/python3.9/http/client.py in _readinto_chunked(self, b)
#     594
#     595                 if len(mvb) <= chunk_left:
# --> 596                     n = self._safe_readinto(mvb)
#     597                     self.chunk_left = chunk_left - n
#     598                     return total_bytes + n
#
# ~/anaconda3/lib/python3.9/http/client.py in _safe_readinto(self, b)
#     639                 n = self.fp.readinto(temp_mvb)
#     640             else:
# --> 641                 n = self.fp.readinto(mvb)
#     642             if not n:
#     643                 raise IncompleteRead(bytes(mvb[0:total_bytes]), len(b))
#
# ~/anaconda3/lib/python3.9/socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.9/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/anaconda3/lib/python3.9/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
